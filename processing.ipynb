# %%
import pandas as pd
import numpy as np
import re
import sys

# %%
raw_data=pd.read_csv("raw_data/app reviews/firefox_app_reviews.csv")

# %%
raw_data.head(20)
# Out:
#                                               comment  star
# 0   Hate chromium based browsers, glad Firefox wen...     5
# 1                      PLSS BRING BACK THE COMBO HAIR     1
# 2   Desktop version has started to automatically d...     1
# 3   Agree with others that not having a new tab op...     2
# 4                                                😍😍😍😍     5
# 5                                           very good     4
# 6                              over all good browser.     5
# 7                                    I love you Diane     5
# 8   I wish I could give it 6 stars. Better than Ch...     5
# 9   pdf reading is still awkward. doable, but awkw...     4
# 10                                     App works nice     5
# 11                                        Quiet goood     5
# 12                                                 Ok     5
# 13  Always had best features with addons. And slig...     5
# 14  Need to select all and bookmark all open tabs ...     3
# 15  As always an amazing browser with privacy feat...     5
# 16                                                  👍     5
# 17                                               good     5
# 18  Claims to have a Dark Theme but all it has is ...     1
# 19  40% of my battery was used in 12 hours , no si...     1

# %%
#removin emojis and any character which is not an alphabet
preprocessed_data1 = raw_data.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))
preprocessed_data1['comment'].astype(bool)
preprocessed_data1=preprocessed_data1[preprocessed_data1['comment'].astype(bool)]

preprocessed_data1.head(20)
# Out:
#                                               comment star
# 0   Hate chromium based browsers, glad Firefox wen...    5
# 1                      PLSS BRING BACK THE COMBO HAIR    1
# 2   Desktop version has started to automatically d...    1
# 3   Agree with others that not having a new tab op...    2
# 5                                           very good    4
# 6                              over all good browser.    5
# 7                                    I love you Diane    5
# 8   I wish I could give it 6 stars. Better than Ch...    5
# 9   pdf reading is still awkward. doable, but awkw...    4
# 10                                     App works nice    5
# 11                                        Quiet goood    5
# 12                                                 Ok    5
# 13  Always had best features with addons. And slig...    5
# 14  Need to select all and bookmark all open tabs ...    3
# 15  As always an amazing browser with privacy feat...    5
# 17                                               good    5
# 18  Claims to have a Dark Theme but all it has is ...    1
# 19  40% of my battery was used in 12 hours , no si...    1
# 20                              Very good and perfect    5
# 21                     very good and step in my email    5

# %%
raw_data.shape
# Out:
# (141747, 2)

# %%
#removing any reviews of length less than 10
lesswordRows = preprocessed_data1[preprocessed_data1['comment'].str.split().str.len()<10].index 
preprocessed_data2 =  preprocessed_data1.drop(lesswordRows, axis = 0)

# %%
preprocessed_data2.head(20)
# Out:
#                                               comment star
# 0   Hate chromium based browsers, glad Firefox wen...    5
# 2   Desktop version has started to automatically d...    1
# 3   Agree with others that not having a new tab op...    2
# 8   I wish I could give it 6 stars. Better than Ch...    5
# 13  Always had best features with addons. And slig...    5
# 14  Need to select all and bookmark all open tabs ...    3
# 15  As always an amazing browser with privacy feat...    5
# 18  Claims to have a Dark Theme but all it has is ...    1
# 19  40% of my battery was used in 12 hours , no si...    1
# 27  it should have translation like Chrome in orde...    4
# 33  It's a great browser, but the performance at P...    4
# 35  Thanks We use it on smartphone barcode scanner...    5
# 38  overall this he very good browser but sometime...    3
# 39  works really well, great browser. just find wa...    4
# 40  It's great but the bookmarks should be a littl...    5
# 45  There's been a huge overhaul compared to the o...    5
# 49  long time user. long time fan, especially of p...    5
# 51  what a complete waste of my time. i got sick o...    1
# 54  Feature request: tab grouping and reordering a...    5
# 55  it popped up and asked me for a review. sign o...    3

# %%
preprocessed_data2.shape
# Out:
# (68417, 2)

# %%
# function to clean web link..punchuations..and stopword...

# def clean_comment(df):
#     all_reviews = list()
#     lines = df["comment"].values.tolist()
#     for text in lines:
#         text = text.lower()
#         pattern = re.compile('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
#         text = pattern.sub('', text)
#         text = re.sub(r"[,.\"!@#$%^&*(){}?/;`~:<>+=-]", "", text)
#         tokens = word_tokenize(text)
#         table = str.maketrans('', '', string.punctuation)
#         stripped = [w.translate(table) for w in tokens]
#         words = [word for word in stripped if word.isalpha()]
#         stop_words = set(stopwords.words("english"))
#         stop_words.discard("not")
#         PS = PorterStemmer()
#         # words = [w for w in words if not w in stop_words]
#         words = [PS.stem(w) for w in words if not w in stop_words]
#         words = ' '.join(words)
#         all_reviews.append(words)
#     return all_reviews

# %%
preprocessed_data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68417 entries, 0 to 141742
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   comment  68417 non-null  object
#  1   star     68417 non-null  object
# dtypes: object(2)
# memory usage: 1.6+ MB

# %%
#convert everything to lowercase
preprocessed_data2['comment'] = preprocessed_data2['comment'].str.lower()

# %%
preprocessed_data2.head(10)
# Out:
#                                               comment star
# 0   hate chromium based browsers, glad firefox wen...    5
# 2   desktop version has started to automatically d...    1
# 3   agree with others that not having a new tab op...    2
# 8   i wish i could give it 6 stars. better than ch...    5
# 13  always had best features with addons. and slig...    5
# 14  need to select all and bookmark all open tabs ...    3
# 15  as always an amazing browser with privacy feat...    5
# 18  claims to have a dark theme but all it has is ...    1
# 19  40% of my battery was used in 12 hours , no si...    1
# 27  it should have translation like chrome in orde...    4

# %%
#removing punctuations
import string
def remove_punctuations(text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')
    return text

# %%
preprocessed_data2["clean_comment"] = preprocessed_data2['comment'].apply(remove_punctuations)

# %%
cleaned_data = preprocessed_data2.drop('comment', 1)

#restructure the dataframe to match the original structure
cleaned_data.rename(columns={'clean_comment': 'comment'},inplace=True)
cleaned_data = cleaned_data[['comment','star']]
cleaned_data.head(10)
#cleaned_data.to_csv('to_process_again_ff_review_raw.csv')
# Out:
# C:\Users\ACER\AppData\Local\Temp/ipykernel_12036/1597517497.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   cleaned_data = preprocessed_data2.drop('comment', 1)
#                                               comment star
# 0   hate chromium based browsers glad firefox went...    5
# 2   desktop version has started to automatically d...    1
# 3   agree with others that not having a new tab op...    2
# 8   i wish i could give it 6 stars better than chr...    5
# 13  always had best features with addons and sligh...    5
# 14  need to select all and bookmark all open tabs ...    3
# 15  as always an amazing browser with privacy feat...    5
# 18  claims to have a dark theme but all it has is ...    1
# 19  40 of my battery was used in 12 hours  no sing...    1
# 27  it should have translation like chrome in orde...    4

# %%
'''
TODO:- 
1.keyword based filtering
2.sentiment analysis classification
3.final csv file
'''
# Out:
# '\nTODO:- \n1.keyword based filtering\n2.sentiment analysis classification\n3.final csv file\n'

# %%
'''
keywords_list = ["button","buttons","menu","menus","list","lists","layout",
                 "item","items","bar","screen","text","image","images","ui",
                 "theme","page","themes","indicator","section","icon","sections",
                 "icons","tab","tabs","colour","color","colours","colors","logo",
                 "dropdown","form","loader","notification","window","font","field",
                 "fields","slider","checkbox","checkboxes","interface","chromium"]

'''
keywords_list=["battery","drain","power","juice","charge","charging","drained",
"draining","charged","heating","heat","mah","MAH","cell","cells","recharge","lithium","drains"
]

# %%
new_raw_ff=cleaned_data

# %%
#attempt ... we'lll delete later...
# new_raw_ff['is_related'] = new_raw_ff['comment'].map(lambda x: max([word in keywords_list for word in x]))
#new_raw_ff[new_raw_ff['comment'].str.contains(keywords_list)]
# def filter_comments(words):
#     return any(word in keywords_list for word in words)

# is_related = new_raw_ff['comment'].apply(filter_comments)

# new_r=new_raw_ff[is_related]

# %%
key_str='|'.join(keywords_list)
print(key_str)
# Out:
# battery|drain|power|juice|charge|charging|drained|draining|chraged|heating|heat|mah|MAH|cell|cells|recharge|lithium|drains

# %%
mask=new_raw_ff.stack().str.contains(key_str).any(level=0)
# Out:
# C:\Users\ACER\AppData\Local\Temp/ipykernel_12036/3929431742.py:1: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.any(level=1) should use df.groupby(level=1).any()
#   mask=new_raw_ff.stack().str.contains(key_str).any(level=0)

# %%
print(mask)
# Out:
# 0         False
# 2         False
# 3         False
# 8         False
# 13        False
#           ...
# 141733    False
# 141735    False
# 141739    False
# 141740    False
# 141742    False
# Length: 68417, dtype: bool

# %%
mask.head(10)
# Out:
# 0     False
# 2     False
# 3     False
# 8     False
# 13    False
# 14    False
# 15    False
# 18    False
# 19     True
# 27    False
# dtype: bool

# %%
new_raw_ff.head()
# Out:
#                                               comment star
# 0   hate chromium based browsers glad firefox went...    5
# 2   desktop version has started to automatically d...    1
# 3   agree with others that not having a new tab op...    2
# 8   i wish i could give it 6 stars better than chr...    5
# 13  always had best features with addons and sligh...    5

# %%
new_raw_ff["is_related"]=new_raw_ff.stack().str.contains(key_str).any(level=0)
# Out:
# C:\Users\ACER\AppData\Local\Temp/ipykernel_12036/1324115680.py:1: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.any(level=1) should use df.groupby(level=1).any()
#   new_raw_ff["is_related"]=new_raw_ff.stack().str.contains(key_str).any(level=0)

# %%
new_raw_ff.head(20)
# Out:
#                                               comment star  is_related
# 0   hate chromium based browsers glad firefox went...    5       False
# 2   desktop version has started to automatically d...    1       False
# 3   agree with others that not having a new tab op...    2       False
# 8   i wish i could give it 6 stars better than chr...    5       False
# 13  always had best features with addons and sligh...    5       False
# 14  need to select all and bookmark all open tabs ...    3       False
# 15  as always an amazing browser with privacy feat...    5       False
# 18  claims to have a dark theme but all it has is ...    1       False
# 19  40 of my battery was used in 12 hours  no sing...    1        True
# 27  it should have translation like chrome in orde...    4       False
# 33  its a great browser but the performance at pc ...    4       False
# 35  thanks we use it on smartphone barcode scanner...    5       False
# 38  overall this he very good browser but sometime...    3       False
# 39  works really well great browser just find way ...    4       False
# 40  its great but the bookmarks should be a little...    5       False
# 45  theres been a huge overhaul compared to the ol...    5       False
# 49  long time user long time fan especially of pri...    5       False
# 51  what a complete waste of my time i got sick of...    1       False
# 54  feature request tab grouping and reordering al...    5       False
# 55  it popped up and asked me for a review sign of...    3       False

# %%
 new_raw_ff['is_related'].value_counts()
# Out:
# False    66566
# True      1851
# Name: is_related, dtype: int64

# %%
kw_filtered_df = new_raw_ff[new_raw_ff['is_related']==True]

# %%
kw_filtered_df
# Out:
#                                                   comment star  is_related
# 19      40 of my battery was used in 12 hours  no sing...    1        True
# 320     promote all you want with turning red but the ...    1        True
# 469     almost awesome still for some reason no matter...    4        True
# 563     the most powerful and user friendly web browse...    5        True
# 626     the background battery drain is baaaaad ive be...    2        True
# ...                                                   ...  ...         ...
# 141387  after read some feed back i want to experience...    5        True
# 141503  excellent web browser on android able to handl...    5        True
# 141504  i love the fire fox  for shadow fight 2 cheats...    5        True
# 141602  guys what hpnd with youtube i notice if im pow...    5        True
# 141627  its a really good app but it drains your batte...    3        True
#
# [1851 rows x 3 columns]

# %%
kw_filtered_df.to_csv(path_or_buf = "filtered_reviews.csv",columns = ["comment"],header=False)

# %%
filtering_result = [] 
for index,row in cleaned_data.iterrows():
    flag=0 # to indicate the for loop was broken because no keyword exists in the comment
    for keyword in keywords_list:
        if keyword in row['comment'].split(" "):
            print(keyword)
            filtering_result.append(True)
            flag=1  #indicate keyword exits in the comment
            break
    if flag == 0:
        filtering_result.append(False)
# Out:
# battery
# battery
# battery
# battery
# power
# power
# battery
# charge
# battery
# battery
# battery
# battery
# power
# battery
# battery
# battery
# battery
# power
# battery
# charge
# battery
# charge
# battery
# cell
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# power
# power
# cell
# power
# battery
# battery
# battery
# battery
# battery
# battery
# charge
# battery
# drain
# cell
# draining
# power
# battery
# power
# cell
# battery
# cell
# battery
# power
# battery
# power
# battery
# power
# power
# battery
# power
# battery
# charging
# power
# cell
# battery
# power
# cell
# battery
# power
# battery
# charging
# cell
# battery
# heat
# battery
# drain
# battery
# charge
# battery
# charge
# battery
# battery
# battery
# charge
# power
# power
# battery
# power
# power
# battery
# power
# power
# cell
# power
# cell
# cell
# battery
# power
# battery
# battery
# power
# heat
# cell
# power
# battery
# power
# battery
# power
# charging
# power
# power
# battery
# cell
# battery
# heating
# power
# cell
# battery
# battery
# battery
# battery
# battery
# battery
# power
# battery
# power
# battery
# cell
# battery
# cell
# power
# battery
# power
# power
# power
# juice
# battery
# cell
# power
# cell
# power
# power
# battery
# battery
# battery
# battery
# battery
# power
# battery
# power
# battery
# battery
# battery
# power
# cell
# battery
# mah
# power
# cell
# charge
# battery
# power
# battery
# power
# battery
# battery
# cell
# battery
# recharge
# battery
# battery
# charge
# battery
# battery
# charge
# power
# power
# power
# charge
# battery
# charge
# battery
# battery
# battery
# drain
# battery
# battery
# power
# power
# charge
# cell
# charge
# power
# battery
# power
# battery
# battery
# battery
# power
# power
# power
# cell
# charge
# cell
# cell
# battery
# battery
# juice
# power
# battery
# charging
# battery
# power
# power
# cell
# battery
# battery
# battery
# power
# power
# power
# power
# power
# battery
# battery
# battery
# charge
# battery
# power
# cell
# battery
# battery
# battery
# charge
# battery
# battery
# power
# battery
# power
# battery
# power
# power
# power
# power
# battery
# power
# battery
# battery
# drain
# cell
# power
# battery
# charging
# cell
# power
# battery
# battery
# battery
# draining
# battery
# drain
# charge
# battery
# battery
# battery
# battery
# power
# power
# cell
# cells
# charge
# battery
# power
# cell
# battery
# battery
# power
# drain
# cell
# battery
# battery
# battery
# power
# power
# charge
# cell
# battery
# battery
# charge
# power
# battery
# cell
# power
# battery
# cell
# battery
# battery
# power
# cell
# battery
# battery
# power
# battery
# battery
# power
# battery
# battery
# charging
# charge
# charge
# drain
# power
# drain
# power
# power
# battery
# power
# battery
# battery
# power
# power
# battery
# cell
# charge
# battery
# heating
# cell
# cell
# battery
# battery
# power
# drain
# battery
# power
# power
# battery
# battery
# power
# battery
# battery
# battery
# power
# battery
# power
# charge
# power
# power
# battery
# power
# drain
# power
# battery
# charge
# battery
# power
# battery
# charge
# charge
# cell
# cell
# power
# power
# power
# charge
# power
# charge
# power
# battery
# cell
# battery
# power
# cell
# battery
# battery
# cell
# charge
# battery
# power
# cell
# charge
# power
# power
# charge
# cell
# power
# power
# battery
# charge
# cell
# cell
# drain
# cell
# power
# battery
# power
# power
# power
# power
# power
# power
# charge
# charge
# battery
# drain
# battery
# cell
# battery
# charge
# power
# drain
# charge
# power
# battery
# power
# power
# power
# battery
# power
# power
# power
# heating
# charge
# battery
# battery
# cell
# battery
# battery
# power
# power
# battery
# power
# cell
# power
# power
# battery
# power
# power
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# cell
# battery
# power
# battery
# battery
# battery
# power
# battery
# power
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# cell
# cell
# power
# charge
# power
# power
# power
# battery
# battery
# cell
# cells
# battery
# battery
# cell
# cell
# cell
# cell
# power
# battery
# cell
# battery
# cell
# battery
# cell
# battery
# cell
# battery
# power
# battery
# battery
# charge
# battery
# power
# battery
# power
# battery
# battery
# battery
# cell
# battery
# cell
# battery
# battery
# battery
# battery
# power
# battery
# battery
# battery
# battery
# battery
# battery
# cell
# battery
# cell
# power
# battery
# power
# battery
# cell
# battery
# draining
# battery
# battery
# cell
# cell
# cells
# power
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# drain
# power
# battery
# battery
# battery
# cell
# battery
# battery
# power
# charge
# battery
# battery
# power
# power
# battery
# battery
# battery
# power
# power
# battery
# battery
# battery
# power
# battery
# power
# power
# battery
# battery
# battery
# battery
# power
# battery
# power
# battery
# cell
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# power
# battery
# cell
# power
# battery
# battery
# power
# battery
# battery
# battery
# battery
# power
# cell
# battery
# battery
# battery
# battery
# battery
# power
# cell
# battery
# drains
# battery
# charge
# battery
# battery
# battery
# battery
# battery
# cell
# battery
# drain
# power
# battery
# battery
# battery
# battery
# battery
# charge
# power
# heating
# battery
# battery
# battery
# cell
# battery
# battery
# battery
# power
# battery
# cell
# charge
# battery
# power
# battery
# battery
# battery
# battery
# power
# heating
# battery
# drain
# battery
# battery
# battery
# battery
# battery
# cell
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# charge
# cell
# drains
# battery
# battery
# drains
# battery
# cell
# battery
# battery
# power
# battery
# battery
# battery
# battery
# power
# battery
# battery
# heat
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# heating
# power
# battery
# power
# charge
# battery
# battery
# power
# battery
# battery
# battery
# cell
# battery
# battery
# power
# battery
# battery
# battery
# cell
# battery
# battery
# battery
# draining
# juice
# battery
# power
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# cell
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# power
# power
# power
# battery
# battery
# cell
# battery
# power
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# cell
# battery
# charge
# battery
# battery
# battery
# heat
# battery
# battery
# power
# battery
# cell
# battery
# cell
# battery
# battery
# cell
# battery
# cell
# battery
# battery
# battery
# battery
# battery
# heat
# charge
# battery
# battery
# battery
# drain
# battery
# battery
# battery
# power
# battery
# cell
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# battery
# power
# battery
# battery
# power
# power
# battery
# battery
# cell
# power
# battery
# battery
# battery
# power
# battery
# battery
# battery
# recharge
# battery
# battery
# battery
# battery
# battery
# battery
# power
# cell
# battery
# battery
# battery
# power
# battery
# battery
# battery
# power
# drain
# battery
# battery
# charging
# drain
# battery
# drains
# battery
# charging
# power
# battery
# drain
# power
# battery

# %%
filtering_result_appended_df = cleaned_data
filtering_result_appended_df["is_related"]=filtering_result
kw_filtered_df = filtering_result_appended_df[filtering_result_appended_df['is_related']==True].drop(["star","is_related"],axis=1)
print(kw_filtered_df.head(10))
# Out:
#                                                 comment
# 19    40 of my battery was used in 12 hours  no sing...
# 320   promote all you want with turning red but the ...
# 469   almost awesome still for some reason no matter...
# 626   the background battery drain is baaaaad ive be...
# 659   animations waste a lot of time please add an o...
# 664   theres a bug only with firefox whenever i put ...
# 736   absolute trash why on earth would you want to ...
# 895   yes fancy giving me my 100 back google stole w...
# 1074  better than google the battery draining invasi...
# 1078  just the fact that its battery consumption is ...

# %%
kw_filtered_df.to_csv(path_or_buf = "filtered_reviews.csv",columns = ["comment"],header=False)

# %%
len(kw_filtered_df)
# Out:
# 842
